# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Students_Performance.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# 1.How many males and females participated in the test

# %%
plt.figure(figsize=(9,6))
sns.countplot(data['gender'])
plt.grid()
plt.title('Gender',fontsize=14)
# Out:
# C:\Users\RASHEED\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gender')

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# > 518 Females and 482 Males participated in the test.

# %% [markdown]
# 2.Students parental level of education

# %%
import statistics
from statistics import mode

# %%
x=pd.Series(data['parental level of education'])
x.describe()
# Out:
# count             1000
# unique               6
# top       some college
# freq               226
# Name: parental level of education, dtype: object

# %% [markdown]
# > While considering the educational level of parents of the students,most of the parents are from the category 'some college.
#   That is most of the parents have colege level of education.

# %% [markdown]
# 3.Who scores the most on average of math,reading and writing based on gender

# %%
D1=data.groupby('gender')['math score','reading score','writing score']
D1.describe()
# Out:
# <ipython-input-7-4a0331f788a7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   D1=data.groupby('gender')['math score','reading score','writing score']
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.590734  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.545643  ...  76.0  100.0         482.0  63.446058
#
#
#               std   min   25%   50%   75%    max
# gender
# ...

# %%
C1=data.groupby('test preparation course')['math score','reading score','writing score']
C1.describe()
# Out:
# <ipython-input-8-dd798da87496>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   C1=data.groupby('test preparation course')['math score','reading score','writing score']
#                         math score                                         \
#                              count      mean        std   min   25%   50%
# test preparation course
# completed                    358.0  69.96648  14.521847  23.0  61.0  70.0
# none                         642.0  63.78972  15.705689   0.0  54.0  64.0
#
#                                      reading score             ...        \
#                           75%    max         count       mean  ...   75%
# test preparation course                                        ...
# completed                79.0  100.0         358.0  74.175978  ...  84.0
# none                     74.0  100.0         642.0  66.417445  ...  76.0
#
# ...

# %% [markdown]
# 1)The 482 male students scored avg mark of 68.82 on Maths than the average mark of 518 female students but 518 female
#   student got average mark 72.59 and 72.46 on reading and writing than the corresponding 482 male students.
# 2)By considering analysis based on Test preparation course students who completed particular course got the higherst avg
#   score on maths ie,69.966 and also the students who completed test preparation course got highest average marks on reading
#   and writing ie,74.175 and 74.684 respectively
#   This clearly depicting that the students who completed test preparation course maintained a higher level of average in maths
#   reading and writing .

# %% [markdown]
# 4.Scoring variation for maths ,reading and writing based on
#   1)Gender
#   2)Test preparation course

# %% [markdown]
# 1.Gender

# %%
F1=data.groupby('gender')['math score']
F2=F1.describe()
F2
# Out:
#         count       mean        std   min   25%   50%   75%    max
# gender
# female  518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male    482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0

# %%
F3=data.groupby('gender')['reading score']
F4=F3.describe()
F4
# Out:
#         count       mean        std   min    25%   50%   75%    max
# gender
# female  518.0  72.590734  14.411018  17.0  63.25  73.0  83.0  100.0
# male    482.0  65.545643  14.149594  23.0  56.00  66.0  76.0  100.0

# %%
F5=data.groupby('gender')['writing score']
F6=F5.describe()
F6
# Out:
#         count       mean        std   min   25%   50%   75%    max
# gender
# female  518.0  72.467181  14.844842  10.0  64.0  74.0  82.0  100.0
# male    482.0  63.446058  14.227225  15.0  53.0  64.0  74.0  100.0

# %% [markdown]
# The Sd is slightly different for male and female students wrt math score,reading score and writing score.

# %% [markdown]
#   2)Test preparation course

# %%
E1=data.groupby('test preparation course')['math score']
E2=E1.describe()
E2
# Out:
#                          count      mean        std   min   25%   50%   75%  \
# test preparation course
# completed                358.0  69.96648  14.521847  23.0  61.0  70.0  79.0
# none                     642.0  63.78972  15.705689   0.0  54.0  64.0  74.0
#
#                            max
# test preparation course
# completed                100.0
# none                     100.0

# %%
E3=data.groupby('test preparation course')['reading score']
E4=E3.describe()
E4
# Out:
#                          count       mean        std   min   25%   50%   75%  \
# test preparation course
# completed                358.0  74.175978  13.537572  37.0  66.0  75.0  84.0
# none                     642.0  66.417445  14.608896  17.0  57.0  67.0  76.0
#
#                            max
# test preparation course
# completed                100.0
# none                     100.0

# %%
E5=data.groupby('test preparation course')['writing score']
E6=E5.describe()
E6
# Out:
#                          count       mean        std   min   25%   50%    75%  \
# test preparation course
# completed                358.0  74.684358  13.236412  36.0  67.0  76.0  83.75
# none                     642.0  64.457944  15.041667  10.0  54.0  65.0  74.00
#
#                            max
# test preparation course
# completed                100.0
# none                     100.0

# %% [markdown]
# Here also the Sd has no greater difference in math score ,writing score and testing score wrt Test preparation course

# %% [markdown]
# 5.Top 25% of studentsa based on their Maths score

# %%
data.sort_values(by='math score',ascending=False).head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data['math score'].describe().to_frame()
# Out:
#         math score
# count  1000.000000
# mean     66.001000
# std      15.569567
# min       0.000000
# 25%      57.000000
# 50%      66.000000
# 75%      77.000000
# max     100.000000

# %% [markdown]
# > The management can give bonus point to the top 25% students that is ,250 students based on their Maths score by refering the
#   above list.
